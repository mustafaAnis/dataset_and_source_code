# %%
import csv
import sys
from nltk.tokenize import word_tokenize
import codecs
import pandas
import numpy
import math

# %%
df = pandas.read_csv("unique_word_translated/unique_word.csv", names = ['second', 'third'], encoding='utf-8-sig')

# %%
urdu_words = df.second.to_list()
roman_words = df.third.to_list()

# %%
# after sepparation
with open('k_eman.csv', encoding = 'utf-8-sig') as file_csv:
    lines_row =file_csv.read().splitlines()
    ct_string = [word_tokenize(i) for i in lines_row]

# %%
punctuation = ['“','“','‘‘',',','-','،','۔','”','!','؟',')','(','.','1','2','3','4','5','6','7','8','9','0','‘',',',"''",'``',' ',':',':’’','’’']
extra_punct = ['’’','“','،',':','”','۔','"',"(",")","؟"]

# %%
# after sepparation
remove_punc=[]
for a in ct_string:
    remove_punc.append([item for item in a if item not in punctuation])

# %%
# after sepparation
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace("؟","")
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace(")","")
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace("(","")
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace('"','')
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace('۔','')
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace('”','')
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace(':','')
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace('،','')
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace('“','')
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace('’’','')
for itemlist in range(len(remove_punc)):
    for item in range(len(remove_punc[itemlist])):
        remove_punc[itemlist][item] = remove_punc[itemlist][item].replace('’','')

# %%
# remove_punc=[]
# for a in ct_string:
#     if a not in punctuation:
#         remove_punc.append(a)

# %%
converted_lines = []
roman_hadees = []
for hadees in remove_punc:
    roman_hadees = []
    for word in hadees:
        try:
            index = urdu_words.index(word)
            a = roman_words[index]
            if isinstance(a,float):
                roman_hadees.append(word)
            else:
                roman_hadees.append(a)
        except:
            print("not found",word)
    str = ' '.join(roman_hadees)
    converted_lines.append(str)
# Out:
# not found ً
# not found ٰ
# not found ٰ
# not found ف٦۲٤
# not found ف٦۲۵
# not found ؐ
# not found ً
# not found ٰ
# not found ۱۷
# not found ف۱۸
# not found ف۳۲
# not found ف۳۳
# not found ف۱۲۹
# not found ف۹٦
# not found ف۱۱۹
# not found ف۱۳۵
# not found ف۱۳٦
# not found ٰ
# not found ٰ

# %%
print(converted_lines)
# Out:
# ['Allah ke naam se shuru jo bohat meharban rehmat wala', 'sab khoobiyan Allah ko jo maalik saaray Jahan walon ka', 'bohat meharban rehmat wala', 'roz jaza ka maalik', 'hum tujhi ko poojain aur tujhi se madad chahain', 'hum ko seedha rasta chala', 'rasta un ka jin par to ne ahsaan kya', 'nah un ka jin par gazabb sun-hwa aur nah behke huoon ka', 'Allah ke naam se shuru jo bohat meharban rehmat wala', 'alum', 'woh buland rutba kitaab quran koi shak ki jagah nahi is mein hadaayat hai dar walon ko', 'woh jobay dekhe imaan layein aur namaz qaim rakhen aur hamari di hui rozi mein se hamari raah mein uthayen', 'aur woh ke imaan layein is par jo ae mehboob tumhari taraf Itra aur jo tum se pehlay Itra aur akhirat par yaqeen rakhen', 'wohi log –apne rab ki taraf se hadaayat par hain aur wohi morad ko pounchanay walay', 'bay shak woh jin ki qismat mein kufar hai inhen barabar hai chahay tum inhen darao ya nah darao woh imaan laane ke nahi', 'Allah ne un ke dilon par aur kaanon par mhrkr di or un ki aankhon par ghata top hai aur un ke liye bara azaab', 'aur kuch log kehte hain ke hum Allah aur pichlle din par imaan laaye aur woh imaan walay nahi', 'fraib diya chahtay hain Allah aur imaan walon ko aur haqeeqat mein fraib nahi dete magar apni jaanun ko aur inhen shaoor nahi', 'un ke dilon mein bemari hai to Allah ne un ki bemari aur barhai aur un ke liye dard naak azaab hai badla un ke jhoot ka', 'aur jo un se kaha jaye zameen mein fasaad nah karo to kehte hain hum to sanwarnay walay hain', 'santa hai wohi fasadi hain magar inhen shaoor nahi', 'aur jab un se kaha jaye imaan lao jaisay aur log imaan laaye hain to kahin kya hum ehmaqon ki terhan imaan le ayen santa hai wohi ahmaq hain magar jantay nahi', 'aur jab imaan walon se milein to kahin hum imaan laaye aur jab –apne shaitano ke paas akailey hon to kahin hum tumahray sath hain hum to yuhin hansi karte hain', 'Allah un se Astehza farmata hai jaisa is ki shaan ke Laiq hai aur inhen dheel deta hai ke apni sar kashi mein bhataktay rahen', 'yeh woh log hain jinhon ne hadaayat ke badlay gumraahi kharidi to un ka soda kuch naffa nah laya aur woh saudey ki raah jantay hi nah thay', 'un ki kahawat is ki terhan hai jis ne aag roshan ki to jab is se aas paas sab jagmaga utha Allah un ka noor le gaya aur inhen andhiyaron mein chore diya ke kuch nahi sujhta', 'behray gungay andhay to woh phir aa ne walay nahi', 'ya jaisay aasman se utartaa pani ke un mein Andheryan hain aur garaj aur chamak –apne kaanon mein ungelian thoons rahay hain kadak ke sabab mout ke dar se aur Allah kafiroon ko ghairay hue hai', 'bijli yun maloom hoti hai ke un ki nigehain uchak le jaye gi jab kuch chamak hui is mein chalne lagey aur jab andhera sun-hwa kharray reh gaye aur Allah chahta to un ke kaan aur ankhen le jata bay shak Allah sab kuch kar sakta hai', 'ae logo –apne rab ko pojo jis ne tumhe aur tum se uglo ko peda kya yeh umeed karte hue ke tumhe parhaiz gari miley', 'jis ne tumahray liye zameen ko bichona aur aasman ko imarat banaya aur aasman se pani utaara to is se kuch phal nikalay tumahray khanay ko to Allah ke liye jaan boojh kar barabar walay nah thehrao', 'aur agar tumhe kuch shak ho is mein jo hum ne –apne un khaas bande par utaara to is jaisi aik sourat to le aao aur Allah ke siwa –apne sab hmaytyon ko bulaa lo agar tum sachey ho', 'phir agar nah laa sako aur hum farmaiye dete hain ke hargiz nah laa sako ge to daro is aag se jis ka eendhan aadmi aur pathar hain tayyar rakhi hai kafiroon ke liye', 'aur khushkhabri day inhen jo imaan laaye aur achay kaam kiye ke un ke liye baagh hain jin ke neechay nehrein rawan jab inhen un baghoon se koi phal khanay ko diya jaye ga soorat dekh kar kahin ge yeh to wohi rizaq hai jo hamein pehlay mila tha aur woh soorat mein milta jalta inhen diya gaya aur un ke liye un baghoon mein suthree Bibyan hain aur woh un mein hamesha rahen ge', 'bay shak Allah is se haya nahi farmata ke misaal samjhane ko kaisi hi cheez ka zikar farmaiye machar ho ya is se barh kar to woh jo imaan laay ...

# %%
myFile = open('roman_translation.csv', 'w')
with myFile:
    writer = csv.writer(myFile)
    for value in converted_lines:
        writer.writerow([value])
myFile.close()
print("Writing complete")
# Out:
# Writing complete
